# %% [markdown]
# # Chapter 4: Implementing a GPT model from Scratch To Generate Text
#
# [Open the source notebook or chapter](https://github.com/jooonkim/ml/tree/main/course/LLMs-from-scratch/ch04) · [Open this notebook in Colab](https://colab.research.google.com/github/jooonkim/ml/blob/main/notebooks/chapter-04.ipynb)
#
# This is my companion notebook for Raschka’s book. I am following the chapter headings, but typing the important code myself. The source material remains linked above; this notebook records what I understand and what I discover.
#
# ## How to use this notebook
#
# 1. Read the chapter offline before coding.
# 2. Return here and write the explanation in my own words.
# 3. Open the matching source notebook only as a reference.
# 4. Type the important implementation into the TODO cells.
# 5. Run one small experiment, attempt the exercises, and record the result.
#
# **Rule:** a TODO cell should stay unfinished until I can explain every important line.

# %% [markdown]
# ## 4.1 Coding an LLM architecture
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “4.1 Coding an LLM architecture” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 4.2 Normalizing activations with layer normalization
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “4.2 Normalizing activations with layer normalization” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 4.3 Implementing a feed forward network with GELU activations
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “4.3 Implementing a feed forward network with GELU activations” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 4.4 Adding shortcut connections
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “4.4 Adding shortcut connections” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 4.5 Connecting attention and linear layers in a transformer block
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “4.5 Connecting attention and linear layers in a transformer block” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 4.6 Coding the GPT model
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “4.6 Coding the GPT model” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 4.7 Generating text
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “4.7 Generating text” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## Summary and takeaways
#
# ### What I can now explain
#
# ### What surprised me
#
# ### What I changed or tested
#
# ### Exercises attempted
#
# ### What remains unclear
#
# ### Next
