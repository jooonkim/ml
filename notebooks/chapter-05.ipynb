# %% [markdown]
# # Chapter 5: Pretraining on Unlabeled Data
#
# [Open the source notebook or chapter](https://github.com/jooonkim/ml/tree/main/course/LLMs-from-scratch/ch05) · [Open this notebook in Colab](https://colab.research.google.com/github/jooonkim/ml/blob/main/notebooks/chapter-05.ipynb)
#
# This is my companion notebook for Raschka’s book. I am following the chapter headings, but typing the important code myself. The source material remains linked above; this notebook records what I understand and what I discover.
#
# ## How to use this notebook
#
# 1. Read the chapter offline before coding.
# 2. Return here and write the explanation in my own words.
# 3. Open the matching source notebook only as a reference.
# 4. Type the important implementation into the TODO cells.
# 5. Run one small experiment, attempt the exercises, and record the result.
#
# **Rule:** a TODO cell should stay unfinished until I can explain every important line.

# %% [markdown]
# ## 5.1 Evaluating generative text models
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.1 Evaluating generative text models” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 5.1.1 Using GPT to generate text
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.1.1 Using GPT to generate text” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 5.1.2 Calculating the text generation loss: cross-entropy and perplexity
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.1.2 Calculating the text generation loss: cross-entropy and perplexity” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 5.1.3 Calculating the training and validation set losses
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.1.3 Calculating the training and validation set losses” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 5.2 Training an LLM
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.2 Training an LLM” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 5.3 Decoding strategies to control randomness
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.3 Decoding strategies to control randomness” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 5.3.1 Temperature scaling
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.3.1 Temperature scaling” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 5.3.2 Top-k sampling
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.3.2 Top-k sampling” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 5.3.3 Modifying the text generation function
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.3.3 Modifying the text generation function” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 5.4 Loading and saving model weights in PyTorch
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.4 Loading and saving model weights in PyTorch” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 5.5 Loading pretrained weights from OpenAI
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “5.5 Loading pretrained weights from OpenAI” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# # file_name = "gpt2-medium-355M.pth"
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “file_name = "gpt2-medium-355M.pth"” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# # file_name = "gpt2-large-774M.pth"
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “file_name = "gpt2-large-774M.pth"” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# # file_name = "gpt2-xl-1558M.pth"
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “file_name = "gpt2-xl-1558M.pth"” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## Summary and takeaways
#
# ### What I can now explain
#
# ### What surprised me
#
# ### What I changed or tested
#
# ### Exercises attempted
#
# ### What remains unclear
#
# ### Next
