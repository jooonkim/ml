# %% [markdown]
# # Chapter 7: Finetuning To Follow Instructions
#
# [Open the source notebook or chapter](https://github.com/jooonkim/ml/tree/main/course/LLMs-from-scratch/ch07) · [Open this notebook in Colab](https://colab.research.google.com/github/jooonkim/ml/blob/main/notebooks/chapter-07.ipynb)
#
# This is my companion notebook for Raschka’s book. I am following the chapter headings, but typing the important code myself. The source material remains linked above; this notebook records what I understand and what I discover.
#
# ## How to use this notebook
#
# 1. Read the chapter offline before coding.
# 2. Return here and write the explanation in my own words.
# 3. Open the matching source notebook only as a reference.
# 4. Type the important implementation into the TODO cells.
# 5. Run one small experiment, attempt the exercises, and record the result.
#
# **Rule:** a TODO cell should stay unfinished until I can explain every important line.

# %% [markdown]
# ## 7.1 Introduction to instruction finetuning
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.1 Introduction to instruction finetuning” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 7.2 Preparing a dataset for supervised instruction finetuning
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.2 Preparing a dataset for supervised instruction finetuning” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 7.3 Organizing data into training batches
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.3 Organizing data into training batches” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 7.4 Creating data loaders for an instruction dataset
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.4 Creating data loaders for an instruction dataset” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 7.5 Loading a pretrained LLM
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.5 Loading a pretrained LLM” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 7.6 Finetuning the LLM on instruction data
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.6 Finetuning the LLM on instruction data” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 7.7 Extracting and saving responses
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.7 Extracting and saving responses” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 7.8 Evaluating the finetuned LLM
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.8 Evaluating the finetuned LLM” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# # 8B model
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “8B model” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 7.9 Conclusions
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.9 Conclusions” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 7.9.1 What's next
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.9.1 What's next” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 7.9.2 Staying up to date in a fast-moving field
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.9.2 Staying up to date in a fast-moving field” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 7.9.3 Final words
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “7.9.3 Final words” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## What's next?
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “What's next?” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## Summary and takeaways
#
# ### What I can now explain
#
# ### What surprised me
#
# ### What I changed or tested
#
# ### Exercises attempted
#
# ### What remains unclear
#
# ### Next
