# %% [markdown]
# # Chapter 3: Coding Attention Mechanisms
#
# [Open Raschka’s source notebook or chapter](https://github.com/rasbt/LLMs-from-scratch/blob/main/ch03/01_main-chapter-code/ch03.ipynb) · [Open this notebook in Colab](https://colab.research.google.com/github/jooonkim/ml/blob/main/notebooks/chapter-03.ipynb)
#
# This is my companion notebook for Raschka’s book. I am following the chapter headings, but typing the important code myself. The source material remains linked above; this notebook records what I understand and what I discover.
#
# ## How to use this notebook
#
# 1. Read the chapter offline before coding.
# 2. Return here and write the explanation in my own words.
# 3. Open the matching source notebook only as a reference.
# 4. Type the important implementation into the TODO cells.
# 5. Run one small experiment, attempt the exercises, and record the result.
#
# **Rule:** a TODO cell should stay unfinished until I can explain every important line.

# %% [markdown]
# ## 3.1 The problem with modeling long sequences
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.1 The problem with modeling long sequences” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 3.2 Capturing data dependencies with attention mechanisms
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.2 Capturing data dependencies with attention mechanisms” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 3.3 Attending to different parts of the input with self-attention
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.3 Attending to different parts of the input with self-attention” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 3.3.1 A simple self-attention mechanism without trainable weights
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.3.1 A simple self-attention mechanism without trainable weights” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 3.3.2 Computing attention weights for all input tokens
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.3.2 Computing attention weights for all input tokens” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 3.4 Implementing self-attention with trainable weights
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.4 Implementing self-attention with trainable weights” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 3.4.1 Computing the attention weights step by step
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.4.1 Computing the attention weights step by step” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 3.4.2 Implementing a compact SelfAttention class
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.4.2 Implementing a compact SelfAttention class” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 3.5 Hiding future words with causal attention
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.5 Hiding future words with causal attention” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 3.5.1 Applying a causal attention mask
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.5.1 Applying a causal attention mask” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 3.5.2 Masking additional attention weights with dropout
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.5.2 Masking additional attention weights with dropout” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 3.5.3 Implementing a compact causal self-attention class
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.5.3 Implementing a compact causal self-attention class” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 3.6 Extending single-head attention to multi-head attention
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.6 Extending single-head attention to multi-head attention” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 3.6.1 Stacking multiple single-head attention layers
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.6.1 Stacking multiple single-head attention layers” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ### 3.6.2 Implementing multi-head attention with weight splits
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “3.6.2 Implementing multi-head attention with weight splits” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## Summary and takeaways
#
# ### What I can now explain
#
# ### What surprised me
#
# ### What I changed or tested
#
# ### Exercises attempted
#
# ### What remains unclear
#
# ### Next
