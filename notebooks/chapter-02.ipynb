# %% [markdown]
# # Chapter 2: Working with Text Data
#
# [Open the source notebook or chapter](https://github.com/jooonkim/ml/tree/main/course/LLMs-from-scratch/ch02) · [Open this notebook in Colab](https://colab.research.google.com/github/jooonkim/ml/blob/main/notebooks/chapter-02.ipynb)
#
# This is my companion notebook for Raschka’s book. I am following the chapter headings, but typing the important code myself. The source material remains linked above; this notebook records what I understand and what I discover.
#
# ## How to use this notebook
#
# 1. Read the chapter offline before coding.
# 2. Return here and write the explanation in my own words.
# 3. Open the matching source notebook only as a reference.
# 4. Type the important implementation into the TODO cells.
# 5. Run one small experiment, attempt the exercises, and record the result.
#
# **Rule:** a TODO cell should stay unfinished until I can explain every important line.

# %% [markdown]
# ## 2.1 Understanding word embeddings
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “2.1 Understanding word embeddings” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 2.2 Tokenizing text
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “2.2 Tokenizing text” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 2.3 Converting tokens into token IDs
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “2.3 Converting tokens into token IDs” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 2.4 Adding special context tokens
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “2.4 Adding special context tokens” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 2.5 BytePair encoding
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “2.5 BytePair encoding” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 2.6 Data sampling with a sliding window
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “2.6 Data sampling with a sliding window” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 2.7 Creating token embeddings
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “2.7 Creating token embeddings” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## 2.8 Encoding word positions
#
# **Before coding:** What is this section trying to compute? What are its inputs and outputs? What should I be able to explain after running it?

# %%
# TODO: Type the important implementation for “2.8 Encoding word positions” yourself.
# Do not paste the source notebook wholesale.
# First write down the shapes, inputs, outputs, and one thing you want to test.

# %% [markdown]
# ## Summary and takeaways
#
# ### What I can now explain
#
# ### What surprised me
#
# ### What I changed or tested
#
# ### Exercises attempted
#
# ### What remains unclear
#
# ### Next
